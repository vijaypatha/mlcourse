# %% [markdown]
# # Contents
#
# - Fundamentals
# - Get to know the outcome variable
# - Which feature should i understand better?
#     - Feature Selection

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/telecom_churn.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %% [markdown]
# ### Notes
# - 20 Features (Inputs), 3333 Observations
# - 1 Label (output)
#     - (Churn: False (1), Ture (0))
# - 3 Cateagorical variables
# - No Null data
# - No duplicated

# %% [markdown]
# ## Lets get to know the outcome/dependent variable or label

# %%
df['Churn'].value_counts(normalize = True)
# Out:
# False    0.855086
# True     0.144914
# Name: Churn, dtype: float64

# %% [markdown]
# ### Notes
# - 14.5% of the sample set churned. Might be a big problem.

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt 
import seaborn as sns
sns.set() # Set aesthetic parameters in one step.

# %config InlineBackend.figure_format = 'svg'

# %%
sns.countplot(data=df, x = 'Churn')

# %% [markdown]
# ## Feature Selection

# %%
sns.heatmap(df.corr(),cmap="Spectral" )

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# #### Notes
# - Based on the corrleation matrix, features Customer service calls, 'Total day minutes', 'Total day charge' seems to be important

# %% [markdown]
# ## Key Features

# %%
sns.countplot('Customer service calls', data = df,hue='Churn')
